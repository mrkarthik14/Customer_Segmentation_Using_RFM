# %%
# Python libraries
# !pip install pandas numpy matplotlib seaborn
# !pip install scikit-learn scipy
# !pip install plotly
# !pip install jupyter

# Tableau Public (Free) - Download from tableau.com

# %%
# !pip install sqlite3
# Out:
# ERROR: Could not find a version that satisfies the requirement sqlite3 (from versions: none)
# ERROR: No matching distribution found for sqlite3

# %%
# import required libaries
import sqlite3
import pandas as pd
import os

# %%
# create python with sqlite3 using conn command
conn = sqlite3.connect('D:\\project\\Customer Segmentation using RFM\\notebooks\\01_data_loading.ipynb')
cursor = conn.cursor()

# %%
# define the datapath of csv files
data_path = 'data/raw/'

# %%
# create tables and map with csv files

tables={
    'customers':'olist_customers_dataset.csv',
    'geolocation':'olist_geolocation_dataset.csv',
    'order_items':'olist_order_items_dataset.csv',
    'order_payments':'olist_order_payments_dataset.csv',
    'order_reviews':'olist_order_reviews_dataset.csv',
    'orders':'olist_orders_dataset.csv',
    'products':'olist_products_dataset.csv',
    'sellers':'olist_sellers_dataset.csv',
    'category_translation':'product_category_name_translation.csv'
}

# %%
# load each csv files into sqlite3

for table_name, csv_file in tables.items():
    print(f"loading {table_name}..........")
    df = pd.read_csv(os.path.join(data_path,tables))
    df.to_sql(table_name, conn, if_exists = 'replace', index =false)
# Out:
#   Cell In[22], line 3
#     for table_name, csv_file in tables.items:
#                                              ^
# SyntaxError: incomplete input
